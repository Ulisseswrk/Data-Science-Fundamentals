# %%
import pandas as pd
url1 = "https://raw.githubusercontent.com/alura-cursos/pandas/refs/heads/main/superstore_data.csv"
df = pd.read_csv(url1, sep = ",")
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
dados_selecao = pd.read_csv(url1, usecols=[0,1,4]) # Use cols usa as colunas x,y,z ou 0,1,2
dados_selecao.head()
# Out:
#       Id  Year_Birth   Income
# 0   1826        1970  84835.0
# 1      1        1961  57091.0
# 2  10476        1958  67267.0
# 3   1386        1967  32474.0
# 4   5371        1989  21474.0

# %%
dados_selecao.to_csv("clientes_mercado.csv") # Salva os arquivos

# %%
#Exercício de leitura de arquivo ISO_8859-1, Pandas não lê caracteres especiais sem especificar o encoding previamente
url2 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/dados_sus.csv'
dados = pd.read_csv(url2,encoding ='ISO-8859-1', sep=";",skiprows=3,skipfooter=9,engine='python')

# %%
#Salvando arquivos do Excel (xlsx) | ?raw=True
url3 = 'https://github.com/alura-cursos/Pandas/blob/main/emissoes_CO2.xlsx?raw=True'
dados_co2 = pd.read_excel(url3)
dados_co2.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Oléo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    0.0     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# 3     NaN    NaN         NaN
# 4     NaN    NaN         NaN

# %%
pd.ExcelFile(url3).sheet_names # Descobrir as diferentes páginas da nossa planilha
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %%
percapita = pd.read_excel(url,sheet_name='emissoes_percapita') # Lendo a segunda página
percapita.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Óleo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    NaN     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    NaN     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    NaN     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    NaN     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    NaN     NaN   NaN  NaN      NaN
#
#    Queima  Outro
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN

# %%
fontes = pd.read_excel(url,sheet_name='fontes') # Lendo a terceira página
fontes.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano   Total  Carvão    Oléo     Gás  \
# 0  Afeganistão                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afeganistão                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afeganistão                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afeganistão                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afeganistão                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cimento  Queima   Outro Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]

# %%
intervalo = pd.read_excel(url, sheet_name='emissoes_C02', usecols='A:D') # Selecionando das colunas A até a D
intervalo.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750    0.0
# 1  Afeganistão                AFG  1751    0.0
# 2  Afeganistão                AFG  1752    0.0
# 3  Afeganistão                AFG  1753    0.0
# 4  Afeganistão                AFG  1754    0.0

# %%
intervalo_2 = pd.read_excel(url, sheet_name='emissoes_C02', usecols='A:D',nrows=10) #Nrows = número de linhas
intervalo_2.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750      0
# 1  Afeganistão                AFG  1751      0
# 2  Afeganistão                AFG  1752      0
# 3  Afeganistão                AFG  1753      0
# 4  Afeganistão                AFG  1754      0

# %%
percapita.to_excel('co2_percapita.xlsx', index=False)

# %%
url4 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/pacientes.json'
dados_pacientes = pd.read_json(url4) # Lendo arquivos json organizados

# %%
dados_pacientes.head()
# Out:
#    ID_paciente Doenca_cardiaca    IMC Fumante Consumo_alcool  AVC  \
# 0            0             Nao  16.60     Sim            Nao  Nao
# 1            1             Nao  20.34     Nao            Nao  Sim
# 2            2             Nao  26.58     Sim            Nao  Nao
# 3            3             Nao  24.21     Nao            Nao  Nao
# 4            4             Nao  23.71     Nao            Nao  Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Sexo_biologico  \
# 0             3            30                  Nao       Feminino
# 1             0             0                  Nao       Feminino
# 2            20            30                  Nao      Masculino
# 3             0             0                  Nao       Feminino
# 4            28             0                  Sim       Feminino
#
#   Faixa_etaria    Raca Diabetes Atividade_fisica Saude_geral  Horas_sono Asma  \
# 0        55-59  Branca      Sim              Sim   Muito boa           5  Sim
# ...

# %%
url5 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/pacientes_2.json'
dados_pacientes2 = pd.read_json(url5) # Lendo arquivos json desorganizados
dados_pacientes2.head()
# Out:
#                                     Pesquisa   Ano  \
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# 2  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_bi...
# 1  {'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_...
# 2  {'ID': '03', 'Faixa_etaria': '65-69', 'Sexo_bi...

# %%
df_normalizado = pd.json_normalize(dados_pacientes2['Pacientes']) #Ajeitar os dados com suas respectivas cols
df_normalizado.head()
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
df_normalizado.to_json('historico_pacientes_normalizado.json')

# %%
pd.read_json(#Url do arquivo json)

# %%
import requests
import json

# %%
dados_usuarios = requests.get('https://jsonplaceholder.typicode.com/users') #Carrega os dados de uma API ficticia
resultado = json.loads(dados_usuarios.text) #Transforma os dados coletados em objetos python (str)
pd.DataFrame(resultado) #Converte por fim, a um Data Frame em Pandas
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# ...

# %%
#import requests
#import json

dados_usuarios = requests.get('https://jsonplaceholder.typicode.com/users') #Pega os dados de uma API que gera nomes ficticios 
resultado = json.loads(dados_usuarios.text) #Transforma os dados em str

dados_normalizados = pd.json_normalize(resultado,sep='_') #Ajeita os valores pra não ficar tudo esquisito
dados_normalizados
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                    phone        website     address.street address.suite  \
# ...

# %%
#Lendo o arquivo html e detectando tags table (tipo = list)
url = 'https://en.wikipedia.org/wiki/AFI%27s_100_Years...100_Movies'
dados_html = pd.read_html(url)
dados_html
# Out:
# [                      Film  Release year              Director  \
#  0             Citizen Kane          1941          Orson Welles
#  1               Casablanca          1942        Michael Curtiz
#  2            The Godfather          1972  Francis Ford Coppola
#  3       Gone with the Wind          1939        Victor Fleming
#  4       Lawrence of Arabia          1962            David Lean
#  ..                     ...           ...                   ...
#  118        Sophie's Choice          1982        Alan J. Pakula
#  119  The Last Picture Show          1971     Peter Bogdanovich
#  120     Do the Right Thing          1989             Spike Lee
#  121           Blade Runner          1982          Ridley Scott
#  122              Toy Story          1995         John Lasseter
#
#                                Production companies 1998 Rank 2007 Rank
#  0                               RKO Radio Pictures         1         1
# ...

# %%
len(dados_html)
top_filmes = dados_html[0]
top_filmes
# Out:
#                       Film  Release year              Director  \
# 0             Citizen Kane          1941          Orson Welles
# 1               Casablanca          1942        Michael Curtiz
# 2            The Godfather          1972  Francis Ford Coppola
# 3       Gone with the Wind          1939        Victor Fleming
# 4       Lawrence of Arabia          1962            David Lean
# ..                     ...           ...                   ...
# 118        Sophie's Choice          1982        Alan J. Pakula
# 119  The Last Picture Show          1971     Peter Bogdanovich
# 120     Do the Right Thing          1989             Spike Lee
# 121           Blade Runner          1982          Ridley Scott
# 122              Toy Story          1995         John Lasseter
#
#                               Production companies 1998 Rank 2007 Rank
# 0                               RKO Radio Pictures         1         1
# ...

# %%
top_filmes.to_html('top_filmes.html') #Salvando o arquivo como html mas organizando os dados

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/imdb_top_1000.xml'
dados_imdb = pd.read_xml(url) #Lendo arquivo xml
dados_imdb.head(1)
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
#
#                Series_Title Released_Year Certificate  Runtime  Genre  \
# 0  The Shawshank Redemption          1994           A  142 min  Drama
#
#    IMDB_Rating                                           Overview  Meta_score  \
# 0          9.3  Two imprisoned men bond over a number of years...        80.0
#
#          Director        Star1           Star2       Star3           Star4  \
# 0  Frank Darabont  Tim Robbins  Morgan Freeman  Bob Gunton  William Sadler
#
#    No_of_Votes       Gross
# 0      2343110  28,341,469

# %%
dados_imdb.to_xml('filmes_imdb.xml') #Salvando os arquivos xml

# %%
Chegou a hora de testar os conhecimentos desenvolvidos durante a aula.

Vanessa é uma cientista de dados que está realizando algumas análises com dados ambientais. Ela está desenvolvendo um projeto para avaliar o impacto ambiental das atividades humanas em diferentes países do mundo, mas para isso precisa das estimativas populacionais desses países. Ao pesquisar na internet, encontrou uma tabela de estimativas populacionais em um artigo da página Wikipédia.

Assim como Vanessa, seu desafio é obter um DataFrame da tabela que contém as informações do número de habitantes de cada país.

# %%
url = 'https://pt.wikipedia.org/wiki/Lista_de_pa%C3%ADses_por_popula%C3%A7%C3%A3o'
dados_ambientais = pd.read_html(url)

# %%
len(dados_ambientais)
# Out:
# 3

# %%
df_ambiente = dados_ambientais[0]
df_ambiente
# Out:
#      Unnamed: 0 Posição    País (ou território dependente) Estimativa da ONU  \
# 0           NaN       1                              Índia     1 417 492 000
# 1           NaN       2                      China[nota 1]     1.407.934.000
# 2           NaN       3                     Estados Unidos       342.181.000
# 3           NaN       4                          Indonésia       285.783.000
# 4           NaN       5                          Paquistão       256 204 000
# ..          ...     ...                                ...               ...
# 245         NaN       –     Ilha de Ascensão (Reino Unido)             1 100
# 246         NaN     195                           Vaticano               879
# 247         NaN       –  Ilhas Cocos (Keeling) (Austrália)               605
# 248         NaN       –     Tristão da Cunha (Reino Unido)               264
# 249         NaN       –       Ilhas Pitcairn (Reino Unido)                67
#
# ...

# %%
df_ambiente.drop(columns=['Unnamed: 0','Estimativa Oficial'], axis=1, inplace=True)
df_ambiente.rename(columns={'País (ou território dependente)':'País'},inplace=True)
df_ambiente
# Out:
#     Posição                               País Estimativa da ONU  \
# 0         1                              Índia     1 417 492 000
# 1         2                      China[nota 1]     1.407.934.000
# 2         3                     Estados Unidos       342.181.000
# 3         4                          Indonésia       285.783.000
# 4         5                          Paquistão       256 204 000
# ..      ...                                ...               ...
# 245       –     Ilha de Ascensão (Reino Unido)             1 100
# 246     195                           Vaticano               879
# 247       –  Ilhas Cocos (Keeling) (Austrália)               605
# 248       –     Tristão da Cunha (Reino Unido)               264
# 249       –       Ilhas Pitcairn (Reino Unido)                67
#
#     Crescimento desde a última estimativa
# 0                             -12 692 000
# 1                              -1 390 000
# 2                              -2 084 000
# ...

# %%
df_ambiente.to_html('df_ambiente.html')

# %%
import sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect

# %%
engine = create_engine('sqlite:///:memory:') #Utilizando o banco sqlite ja integrado no jupyter

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/clientes_banco.csv'
dados = pd.read_csv(url)
dados.head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008809     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1       Apartamento alugado
# ...

# %%
dados.to_sql('clientes', engine, index=False) #Salvando esse df em SQL para manipula-lo
# Out:
# 438463

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes']

# %%
query = 'SELECT * FROM clientes WHERE Categoria_de_renda == "Empregado"'#Fazendo uma consu=lta sql

# %%
empregados = pd.read_sql(query,engine) #Serve para ler uma consulta sql, para ler a tabela inteira usa sql_table

# %%
empregados.to_sql('empregados',con=engine, index=False)
# Out:
# 226059

# %%
pd.read_sql_table('empregados',engine) #Pra ler a tabela inteira e não só a consulta SQL
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008815     46   Ensino superior         Casado                2
# 4          5112956     46   Ensino superior         Casado                2
# ...            ...    ...               ...            ...              ...
# 226054     6837905     43      Ensino médio         Casado                3
# 226055     6837906     43      Ensino médio         Casado                3
# 226056     6839936     34      Ensino médio         Casado                3
# 226057     6840222     43      Ensino médio       Solteiro                1
# 226058     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
pd.read_sql_table('empregados',engine,columns=['ID_Cliente','Grau_escolaridade','Rendimento_anual']) #Lendo apenas x colunas
# Out:
#         ID_Cliente Grau_escolaridade  Rendimento_anual
# 0          5008804   Ensino superior          427500.0
# 1          5008805   Ensino superior          427500.0
# 2          5008806      Ensino médio          112500.0
# 3          5008815   Ensino superior          270000.0
# 4          5112956   Ensino superior          270000.0
# ...            ...               ...               ...
# 226054     6837905      Ensino médio          355050.0
# 226055     6837906      Ensino médio          355050.0
# 226056     6839936      Ensino médio          135000.0
# 226057     6840222      Ensino médio          103500.0
# 226058     6842885      Ensino médio          121500.0
#
# [226059 rows x 3 columns]

# %%
from sqlalchemy import text

# %%
query = text('DELETE FROM clientes WHERE ID_Cliente=5008804') # usamos o text pro sqlalchemy consiga identificar o arquivo certo, evitando falhas de segurança por exemplo
with engine.connect() as conn:
    conn.execute(query)

# %%
query = text('UPDATE clientes SET Grau_escolaridade= "Ensino superior" WHERE ID_Cliente = 5008808')
with engine.connect() as conn:
    conn.execute(query)
    conn.commit()

# %%
pd.read_sql_table('clientes', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52   Ensino superior       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv'
df_exercicio = pd.read_csv(url)
df_exercicio.to_sql('df_sql', engine)
# Out:
# 438463

# %%
df_sql = pd.read_sql_table('df_sql', engine)

# %%
Criar o banco de dados local com a biblioteca SQLAlchemy.
Escrever os dados do arquivo CSV neste banco de dados local.
Realizar três atualizações no banco de dados:
Atualizar o registro do cliente de ID 6840104 que teve o rendimento anual alterado para 300000.
Excluir o registro do cliente de ID 5008809, pois essa pessoa não possui mais conta na instituição financeira.
Criar um novo registro de cliente seguindo as especificações abaixo:
ID_Cliente: 6850985
Idade: 33
Grau_escolaridade: Doutorado
Estado_civil: Solteiro
Tamanho_familia: 1
Categoria_de_renda: Empregado
Ocupacao: TI
Anos_empregado: 2
Rendimento_anual: 290000
Tem_carro: 0
Moradia: Casa/apartamento próprio

# %%
update_query = text('UPDATE df_sql SET Rendimento_anual = 30000 WHERE ID_Cliente = 6840104')

delete_query = text('DELETE FROM df_sql WHERE ID_Cliente = 5008809')

insert_query = text('''INSERT INTO df_sql 
(ID_Cliente,Idade,Grau_escolaridade,Estado_civil,Tamanho_familia,Categoria_de_renda,Ocupacao,Anos_empregado,Rendimento_anual,Tem_carro,Moradia
) VALUES (
6850985,33,'Doutorado','Solteiro',1,
'Empregado','TI',2,290000,0,'Casa/apartamento próprio'
)
''')

with engine.connect() as conn:
    conn.execute(update_query)
    conn.execute(delete_query)
    conn.execute(insert_query)
    conn.commit()

# %%
pd.read_sql_table('df_sql', engine)
# Out:
#            index  ID_Cliente  Idade Grau_escolaridade   Estado_civil  \
# 0            0.0     5008804     32   Ensino superior  União-estável
# 1            1.0     5008805     32   Ensino superior  União-estável
# 2            2.0     5008806     58      Ensino médio         Casado
# 3            3.0     5008808     52      Ensino médio       Solteiro
# 4            5.0     5008810     52      Ensino médio       Solteiro
# ...          ...         ...    ...               ...            ...
# 438458  438459.0     6840222     43      Ensino médio       Solteiro
# 438459  438460.0     6841878     22   Ensino superior       Solteiro
# 438460  438461.0     6842765     59      Ensino médio         Casado
# 438461  438462.0     6842885     51      Ensino médio         Casado
# 438462       NaN     6850985     33         Doutorado       Solteiro
#
#         Tamanho_familia   Categoria_de_renda          Ocupacao  \
# 0                     2            Empregado             Outro
# ...
