# %%
import pandas as pd
url1 = "https://raw.githubusercontent.com/alura-cursos/pandas/refs/heads/main/superstore_data.csv"
df = pd.read_csv(url, sep = ",")
df.head()
# Out:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %%
dados_selecao = pd.read_csv(url1, usecols=[0,1,4]) # Use cols usa as colunas x,y,z ou 0,1,2
dados_selecao.head()
# Out:
#       Id  Year_Birth   Income
# 0   1826        1970  84835.0
# 1      1        1961  57091.0
# 2  10476        1958  67267.0
# 3   1386        1967  32474.0
# 4   5371        1989  21474.0

# %%
dados_selecao.to_csv("clientes_mercado.csv") # Salva os arquivos

# %%
#Exercício de leitura de arquivo ISO_8859-1, Pandas não lê caracteres especiais sem especificar o encoding previamente
url2 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/main/dados_sus.csv'
dados = pd.read_csv(url2,encoding ='ISO-8859-1', sep=";",skiprows=3,skipfooter=9,engine='python')

# %%
#Salvando arquivos do Excel (xlsx) | ?raw=True
url3 = 'https://github.com/alura-cursos/Pandas/blob/main/emissoes_CO2.xlsx?raw=True'
dados_co2 = pd.read_excel(url3)
dados_co2.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Oléo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    0.0     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# 3     NaN    NaN         NaN
# 4     NaN    NaN         NaN

# %%
pd.ExcelFile(url3).sheet_names # Descobrir as diferentes páginas da nossa planilha
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %%
percapita = pd.read_excel(url,sheet_name='emissoes_percapita') # Lendo a segunda página
percapita.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Óleo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    NaN     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    NaN     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    NaN     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    NaN     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    NaN     NaN   NaN  NaN      NaN
#
#    Queima  Outro
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN

# %%
fontes = pd.read_excel(url,sheet_name='fontes') # Lendo a terceira página
fontes.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano   Total  Carvão    Oléo     Gás  \
# 0  Afeganistão                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afeganistão                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afeganistão                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afeganistão                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afeganistão                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cimento  Queima   Outro Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]

# %%
intervalo = pd.read_excel(url, sheet_name='emissoes_C02', usecols='A:D') # Selecionando das colunas A até a D
intervalo.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750    0.0
# 1  Afeganistão                AFG  1751    0.0
# 2  Afeganistão                AFG  1752    0.0
# 3  Afeganistão                AFG  1753    0.0
# 4  Afeganistão                AFG  1754    0.0

# %%
intervalo_2 = pd.read_excel(url, sheet_name='emissoes_C02', usecols='A:D',nrows=10) #Nrows = número de linhas
intervalo_2.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750      0
# 1  Afeganistão                AFG  1751      0
# 2  Afeganistão                AFG  1752      0
# 3  Afeganistão                AFG  1753      0
# 4  Afeganistão                AFG  1754      0

# %%
percapita.to_excel('co2_percapita.xlsx', index=False)

# %%
url4 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/pacientes.json'
dados_pacientes = pd.read_json(url4) # Lendo arquivos json organizados

# %%
dados_pacientes.head()
# Out:
#    ID_paciente Doenca_cardiaca    IMC Fumante Consumo_alcool  AVC  \
# 0            0             Nao  16.60     Sim            Nao  Nao
# 1            1             Nao  20.34     Nao            Nao  Sim
# 2            2             Nao  26.58     Sim            Nao  Nao
# 3            3             Nao  24.21     Nao            Nao  Nao
# 4            4             Nao  23.71     Nao            Nao  Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Sexo_biologico  \
# 0             3            30                  Nao       Feminino
# 1             0             0                  Nao       Feminino
# 2            20            30                  Nao      Masculino
# 3             0             0                  Nao       Feminino
# 4            28             0                  Sim       Feminino
#
#   Faixa_etaria    Raca Diabetes Atividade_fisica Saude_geral  Horas_sono Asma  \
# 0        55-59  Branca      Sim              Sim   Muito boa           5  Sim
# ...

# %%
url5 = 'https://raw.githubusercontent.com/alura-cursos/Pandas/refs/heads/main/pacientes_2.json'
dados_pacientes2 = pd.read_json(url5) # Lendo arquivos json desorganizados
dados_pacientes2.head()
# Out:
#                                     Pesquisa   Ano  \
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# 2  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_bi...
# 1  {'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_...
# 2  {'ID': '03', 'Faixa_etaria': '65-69', 'Sexo_bi...

# %%
df_normalizado = pd.json_normalize(dados_pacientes2['Pacientes']) #Ajeitar os dados com suas respectivas cols
df_normalizado.head()
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
df_normalizado.to_json('historico_pacientes_normalizado.jsom')

# %%
pd.read_json(#Url do arquivo json)

# %%
import requests
import json

# %%
dados_usuarios = requests.get('https://jsonplaceholder.typicode.com/users') #Carrega os dados de uma API ficticia
resultado = json.loads(dados_usuarios.text) #Transforma os dados coletados em objetos python (str)
pd.DataFrame(resultado) #Converte por fim, a um Data Frame em Pandas
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                                              address                  phone  \
# ...

# %%
#import requests
#import json

dados_usuarios = requests.get('https://jsonplaceholder.typicode.com/users') #Pega os dados de uma API que gera nomes ficticios 
resultado = json.loads(dados_usuarios.text) #Transforma os dados em str

dados_normalizados = pd.json_normalize(resultado,sep='_') #Ajeita os valores pra não ficar tudo esquisito
dados_normalizados
# Out:
#    id                      name          username                      email  \
# 0   1             Leanne Graham              Bret          Sincere@april.biz
# 1   2              Ervin Howell         Antonette          Shanna@melissa.tv
# 2   3          Clementine Bauch          Samantha         Nathan@yesenia.net
# 3   4          Patricia Lebsack          Karianne  Julianne.OConner@kory.org
# 4   5          Chelsey Dietrich            Kamren   Lucio_Hettinger@annie.ca
# 5   6      Mrs. Dennis Schulist  Leopoldo_Corkery    Karley_Dach@jasper.info
# 6   7           Kurtis Weissnat      Elwyn.Skiles     Telly.Hoeger@billy.biz
# 7   8  Nicholas Runolfsdottir V     Maxime_Nienow       Sherwood@rosamond.me
# 8   9           Glenna Reichert          Delphine    Chaim_McDermott@dana.io
# 9  10        Clementina DuBuque    Moriah.Stanton     Rey.Padberg@karina.biz
#
#                    phone        website     address.street address.suite  \
# ...
